# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Sagar Maharaj**
# Data Scientist

# %% [markdown]
# _I am interested in data science because it gives insights about data and help us to predict behaviour of outcome in future. Also, it gives insight about hidden opportuinities and possible root cause of problems._

# %% [markdown]
# ### Addition of two numbers

# %%
1+1
# Out:
# 2

# %% [markdown]
# ~~programming is simple~~
#
# - 1st Launch OBM Cloud pack
# - 2nd create project
# - 3rd search asset as "jupyter lab"
#
# [redirect this](https://cloud.ibm.com/)
